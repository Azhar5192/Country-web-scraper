# %%
import csv
from bs4 import BeautifulSoup
import requests
req = requests.get("https://news.ycombinator.com")

box1 = []

# box2 = []
# for i in range(1 , 26):
    
    # if req.status_code != 404:
# page = requests.get(f"https://news.ycombinator.com/?p={i}")

# response = page
# with open(f"data_5/pages{i}.html" , 'w', encoding="utf-8") as f:
#        f.write(page.text)
       # print(f"page {i} is saved")
soup = BeautifulSoup(req.text , 'html.parser')

# infor = soup.find_all("span", class_="titleline")
# for info in infor:
#     title = info.find("a").get_text(strip=True)
#     link = info.find("a")["href"]
   
#     if link.startswith("https"):
#        box1.append([title,link])

# # second section
# point = soup.find_all("span", class_="subline")

# for p in point:
#     points = p.find("span", class_="score").text
#     box2.append(points)
        
# with open("new.csv" , "w", newline="" , encoding="utf-8") as f:  
#     writer = csv.writer(f)
#     writer.writerow(["Title", "Links"])
#     writer.writerows(box)
    
# print("file is read")    
    
# bigbox.append([(box), points])  

table = soup.find_all("span", class_="titleline")

for take in table:
    title = take.find("a").get_text(strip=True)
    link = take.find("a")["href"]
    
    if link.startswith("https"):
        box1.append([title,link])
    

    # points = take.find("span", class_="score")

    
    
box1,len(box1)
# Out:
# ([['Ooh.directory: a place to find good blogs that interest you',
#    'https://ooh.directory/'],
#   ['Zig – io_uring and Grand Central Dispatch std.Io implementations landed',
#    'https://ziglang.org/devlog/2026/#2026-02-13'],
#   ['Show HN: Sameshi – a ~1200 Elo chess engine that fits within 2KB',
#    'https://github.com/datavorous/sameshi'],
#   ['Show HN: I spent 3 years reverse-engineering a 40 yo stock market sim from 1986',
#    'https://www.wallstreetraider.com/story.html'],
#   ['Show HN: SQL-tap – Real-time SQL traffic viewer for PostgreSQL and MySQL',
#    'https://github.com/mickamy/sql-tap'],
#   ['How many registers does an x86-64 CPU have? (2020)',
#    'https://blog.yossarian.net/2020/11/30/How-many-registers-does-an-x86-64-cpu-have'],
#   ['Ars Technica makes up quotes from Matplotlib maintainer; pulls story',
#    'https://infosec.exchange/@mttaggart/116065340523529645'],
#   ['Babylon 5 is now free to watch on YouTube',
# ...
