# %%
# import requests
# import csv
# from bs4 import BeautifulSoup 

# details = []

# req = requests.get("https://www.codewithharry.com/")

# with open("data/index.html" , "w") as f:

    # req.status_code

# %%
import csv
from bs4 import BeautifulSoup

carlist = []

# Read HTML file
with open("data/index.html", encoding="utf-8") as f:

soup = BeautifulSoup(f.read(), "html.parser")


container = soup.find("div", class_="react-swipable-view-container")

car_sections = container.select_all("div", {"data-swipable": "true"})

# Combine safely
for car in car_sections:

      print(car.text)
    # carlist.append([car_name, car_price])


# Save to CSV
# with open("cars.csv", "w", newline="", encoding="utf-8") as f:

#     writer = csv.writer(f)

#     writer.writerow(["Car Name", "Price"])
#     writer.writerows(carlist)


# print("File saved in cars.csv ✅")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 15
#      10 soup = BeautifulSoup(content, "html.parser")
#      13 container = soup.find("div", class_="react-swipable-view-container")
# ---> 15 car_sections = container.select_all("div", {"data-swipable": "true"})
#      17 # Combine safely
#      18 for car in car_sections:
#
# AttributeError: 'NoneType' object has no attribute 'select_all'
