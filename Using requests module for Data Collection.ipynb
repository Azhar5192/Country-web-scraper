# %%
# import requests

# %%
# url = "https://books.toscrape.com/"
# a = requests.get(url)
# # a.text
# # a.text # i put this html in htmls 

# with open(f"htmls/page.html", 'w') as f:
#     f.write(a.text)

# %%
# for i in range(1,51):
#     a = requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
#     response = a

#     # check page is exist or not
#     if response.status_code == 404:
#         print(f"❌ Page {i} not found (Skipped)")
          
#     else:
#         with open(f"htmls/page{i}.html", "w",encoding="utf=8") as f:
#             f.write(a.text)
#         # print(f"✅ Page {i} downloaded successfully")

# %%
# import requests
# import os

# os.makedirs("htmls", exist_ok=True)

# for i in range(1, 51):

#     # Special case for page 1
#     if i == 1:
#         url = "https://books.toscrape.com/index.html"
#     else:
#         url = f"https://books.toscrape.com/catalogue/page-{i}.html"

#     response = requests.get(url)

#     # Check both status AND content
#     if response.status_code == 200 and "404" not in response.text.lower():

#         with open(f"htmls/page{i}.html", "w", encoding="utf-8") as f:
#             f.write(response.text)

#         print(f"✅ Page {i} downloaded successfully")

#     else:
#         print(f"❌ Page {i} is invalid (Skipped)")

# %%
# import requests
# a = requests.get("https://quotes.toscrape.com/")
# for i in range(1,11):
#     a = requests.get(f"https://quotes.toscrape.com/page/{i}/")
#     with open(f"zillow/index{i}.html", 'w' , encoding="utf-8") as f:
#         f.write(a.text)
# print("all tags loaded succesfully")

# %%
# import requests
# from bs4 import BeautifulSoup

# base_url = "http://quotes.toscrape.com"
# page = 1

# all_quotes = []

# while True: # run loop until say stop

#     url = f"{base_url}/page/{page}/"
#     res = requests.get(url)  # requests from website and store data in res

#     if res.status_code != 200:   #if page is empty → STOP. 
#         break

#     soup = BeautifulSoup(res.text, "html.parser")  # beatutifulsoup takes raw html -> convert it into searchable format

#     quotes = soup.find_all("div", class_="quote") # blocks in pages each pages = one quotes + author

#     if not quotes: # stop if no quotes found
#         break

#     for q in quotes:  # loop though each quotes box 
#         text = q.find("span", class_="text").text # extracting quotes text 
#         author = q.find("small", class_="author").text  # extracting author names

#         all_quotes.append((text, author)) # add quotes and their author names as touples

#     print(f"Scraped Page {page}") # printing progress pages 
#     page += 1 # move to the next  page 
 

# print("\nTotal Quotes:", len(all_quotes)) # we are outside from the loop and printing total quotes length

# # Show first 5
# # for q in all_quotes[:5]:
# #     print("\n", q)
# import csv

# with open("quotes.csv", "w", newline="", encoding="utf-8") as f:
#     writer = csv.writer(f)
#     writer.writerow(["Quote", "Author"])
#     writer.writerows(all_quotes)

# print("Saved to quotes.csv")
# # ✅ Starts from page 1
# # ✅ Downloads page
# # ✅ Finds all quotes
# # ✅ Extracts text + author
# # ✅ Saves in list
# # ✅ Goes to next page
# # ✅ Stops at last page
# # ✅ Prints result

# %%
# import pandas as pd

# df = pd.read_csv("quotes.csv")
# # df

# %%
# df.head()

# %%
# df.tail()

# %%
# # from bs4 import BeautifulSoup
# import requests

# a = requests.get("https://books.toscrape.com/")

# a.text
